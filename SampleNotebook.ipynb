# %%
from BitModel import models  # Importing the functions

# %%
# Usage example with input and output paths
input_file_path = "Example/Input_File.xlsx"
output_file_path = "Example/Output_File.xlsx"
models.process_excel(input_file_path, output_file_path)
